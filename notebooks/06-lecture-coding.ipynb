# %% [markdown]
# # Lecute 6 coding

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

from sklearn.cluster import KMeans

# helpers
import sys
sys.path.append(r"C:\Users\terje\DataspellProjects\tub_advanced_ds")
from src.helpers import feature_importance_plot
from src.helper_classes import EDA, Model

# %%
uk_customers = EDA("../data/online_history_cleaned.pkl")

# %%
# Check shape and info
uk_customers.summary()
# Out:
# ______________________________ Info ______________________________
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397925 entries, 0 to 531285
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      397925 non-null  object
#  1   StockCode    397925 non-null  object
#  2   Quantity     397925 non-null  int64
#  3   InvoiceDate  397925 non-null  datetime64[ns]
#  4   Price        397925 non-null  float64
#  5   CustomerID   397925 non-null  object
#  6   Country      397925 non-null  object
#  7   Description  397925 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 27.3+ MB
# None
# ______________________________ Sample rows ______________________________
#
#        Invoice StockCode  Quantity         InvoiceDate  Price CustomerID  \
# 165255  551142     21340         3 2011-04-26 13:22:00  12.75     u17613
# ...

# %%
uk_customers.identify_missing_data()
# Out:
#              percent_missing           dtype
# Invoice                  0.0          object
# StockCode                0.0          object
# Quantity                 0.0           int64
# InvoiceDate              0.0  datetime64[ns]
# Price                    0.0         float64
# CustomerID               0.0          object
# Country                  0.0          object
# Description              0.0          object

# %%
uk_customers.df = uk_customers.df.drop_duplicates()
uk_customers.df
# Out:
#        Invoice StockCode  Quantity         InvoiceDate  Price CustomerID  \
# 0       536365    85123A         6 2010-12-01 08:26:00   2.55      u1785
# 1       536365     71053         6 2010-12-01 08:26:00   3.39      u1785
# 2       536365    84406B         8 2010-12-01 08:26:00   2.75      u1785
# 3       536365    84029G         6 2010-12-01 08:26:00   3.39      u1785
# 4       536365    84029E         6 2010-12-01 08:26:00   3.39      u1785
# ...        ...       ...       ...                 ...    ...        ...
# 531281  581587     22899         6 2011-12-09 12:50:00   2.10      u1268
# 531282  581587     23254         4 2011-12-09 12:50:00   4.15      u1268
# 531283  581587     23255         4 2011-12-09 12:50:00   4.15      u1268
# 531284  581587     22138         3 2011-12-09 12:50:00   4.95      u1268
# 531285  581587      POST         1 2011-12-09 12:50:00  18.00      u1268
#
#                Country                          Description
# ...
